# %%
println("start")

include("MPLAMarketClearingLib/src/lib/experiments/test_experiment.jl")

TestExperiment.RunTest()

println("done")
# Out:
# start
# test_1775038424.299000
# mismatch: 0.0 != -2.2737367544323206e-13
# 2×4 DataFrame
#  Row │ Name                      PositiveImbalance  NegativeImbalance  AbsoluteImbalance
#      │ String                    Float64            Float64            Float64
# ─────┼───────────────────────────────────────────────────────────────────────────────────
#    1 │ rolling_with_ramps                  184.686           -217.335            402.021
#    2 │ fixed_horizon_status_quo           1067.18           -1151.64            2218.82
# mismatch: 0.0 != -2.2737367544323206e-13
# SEW comparison: rolling_with_ramps / fixed_horizon_status_quo 1.000268645470102
# SEW with storage comparison: rolling_with_ramps / fixed_horizon_status_quo 1.0002684217368663
# 2×6 DataFrame
#  Row │ Name                      SEW        ProducerSurplus  ConsumerSurplus  StoragePayments  Emissions
#      │ String                    Float64    Float64          Float64          Float64          Float64
# ...

# %%
using CSV
using DataFrames
df = DataFrame(A=1:3, B=5:7)
CSV.write("../DATA/test.csv", df) # relative path to where I execute from or the file?
# Out:
# "../DATA/test.csv"
