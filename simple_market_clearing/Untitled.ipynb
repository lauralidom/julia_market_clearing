# %%
include("market_clearing_rolling.jl")
# Out:
# Rolling Horizon Market Clearing Simulation
# Simulation: 2 days + 1 prep hour | Look-ahead: 24 hours | Reclear frequency: every 1 hour(s)
#
# Clearing 1 (global hour 0):
