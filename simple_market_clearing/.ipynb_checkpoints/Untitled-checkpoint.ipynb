# %%
include("market_clearing_rolling.jl")
# Out:
# LoadError: ArgumentError: Package XLSX [fdbf4ff8-1666-58a4-91e7-1b58723a45e0] is required but does not seem to be installed:
#  - Run `Pkg.instantiate()` to install all recorded dependencies.
#
# in expression starting at C:\Users\Atkin005\OneDrive - Universiteit Utrecht\Documents\julia\Code\simple_market_clearing\src\visualisation.jl:3
# in expression starting at C:\Users\Atkin005\OneDrive - Universiteit Utrecht\Documents\julia\Code\simple_market_clearing\market_clearing_rolling.jl:11
#
# Stacktrace:
#   [1] __require_prelocked(pkg::Base.PkgId, env::String)
#     @ Base .\loading.jl:2615
#   [2] _require_prelocked(uuidkey::Base.PkgId, env::String)
#     @ Base .\loading.jl:2493
#   [3] macro expansion
#     @ .\loading.jl:2421 [inlined]
#   [4] macro expansion
#     @ .\lock.jl:376 [inlined]
#   [5] __require(into::Module, mod::Symbol)
#     @ Base .\loading.jl:2386
#   [6] require(into::Module, mod::Symbol)
#     @ Base .\loading.jl:2362
# ...
